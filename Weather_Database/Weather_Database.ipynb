# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
len(coordinates)
# Out:
# 2000

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
import requests
requests.__version__
# Out:
# '2.22.0'

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | angoche
# Processing Record 2 of Set 1 | broome
# Processing Record 3 of Set 1 | bambous virieux
# Processing Record 4 of Set 1 | chokurdakh
# Processing Record 5 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 6 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 1 | junin
# Processing Record 8 of Set 1 | port moresby
# Processing Record 9 of Set 1 | kot radha kishan
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | port alfred
# Processing Record 12 of Set 1 | saint-augustin
# Processing Record 13 of Set 1 | norman wells
# Processing Record 14 of Set 1 | dikson
# Processing Record 15 of Set 1 | okhotsk
# Processing Record 16 of Set 1 | pevek
# Processing Record 17 of Set 1 | clyde river
# Processing Record 18 of Set 1 | skjervoy
# Processing Record 19 of Set 1 | morrinhos
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | grindavik
# Processing Record 22 of Set 1 | union
# Processing Record 23 of Set 1 | wawa
# Processing Record 24 of Set 1 | thompson
# Processing Record 25 of Set 1 | tarko-sale
# Processing Record 26 of Set 1 | mana
# Processing Record 27 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 1 | kaitangata
# Processing Record 29 of Set 1 | eureka
# Processing Record 30 of Set 1 | baker city
# Processing Record 31 of Set 1 | berdigestyakh
# Processing Record 32 of Set 1 | bilibino
# Processing Record 33 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 1 | gravdal
# Processing Record 35 of Set 1 | buchanan
# Processing Record 36 of Set 1 | inuvik
# Processing Record 37 of Set 1 | dubbo
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | hervey bay
# Processing Record 40 of Set 1 | fortuna
# Processing Record 41 of Set 1 | ribeira grande
# Processing Record 42 of Set 1 | qaanaaq
# Processing Record 43 of Set 1 | cayenne
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | katangli
# Processing Record 46 of Set 1 | yellowknife
# Processing Record 47 of Set 1 | yumen
# Processing Record 48 of Set 1 | bubaque
# Processing Record 49 of Set 1 | kedrovyy
# Processing Record 50 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 2 | rikitea
# Processing Record 2 of Set 2 | mataura
# Processing Record 3 of Set 2 | luderitz
# Processing Record 4 of Set 2 | sunndalsora
# Processing Record 5 of Set 2 | kodiak
# Processing Record 6 of Set 2 | hilo
# Processing Record 7 of Set 2 | jesus carranza
# Processing Record 8 of Set 2 | wanaka
# Processing Record 9 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 2 | aravete
# Processing Record 11 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 2 | lazaro cardenas
# Processing Record 13 of Set 2 | kimbe
# Processing Record 14 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | lata
# Processing Record 17 of Set 2 | atuona
# Processing Record 18 of Set 2 | tampakan
# Processing Record 19 of Set 2 | khatanga
# Processing Record 20 of Set 2 | ipixuna
# Processing Record 21 of Set 2 | sar-e pul
# Processing Record 22 of Set 2 | busselton
# Processing Record 23 of Set 2 | meulaboh
# Processing Record 24 of Set 2 | stoyba
# City not found. Skipping...
# Processing Record 25 of Set 2 | kikwit
# Processing Record 26 of Set 2 | avera
# Processing Record 27 of Set 2 | samfya
# Processing Record 28 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 2 | new norfolk
# Processing Record 30 of Set 2 | albany
# Processing Record 31 of Set 2 | provideniya
# Processing Record 32 of Set 2 | tasiilaq
# Processing Record 33 of Set 2 | narsaq
# Processing Record 34 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 2 | tiksi
# Processing Record 36 of Set 2 | barcelos
# Processing Record 37 of Set 2 | san buenaventura
# Processing Record 38 of Set 2 | gold coast
# Processing Record 39 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 2 | porto nacional
# Processing Record 41 of Set 2 | butaritari
# Processing Record 42 of Set 2 | barrow
# Processing Record 43 of Set 2 | cape town
# Processing Record 44 of Set 2 | east london
# Processing Record 45 of Set 2 | bengkulu
# Processing Record 46 of Set 2 | puerto ayora
# Processing Record 47 of Set 2 | ponta do sol
# Processing Record 48 of Set 2 | vardo
# Processing Record 49 of Set 2 | bardiyah
# Processing Record 50 of Set 2 | shache
# Processing Record 1 of Set 3 | te anau
# Processing Record 2 of Set 3 | saldanha
# Processing Record 3 of Set 3 | georgetown
# Processing Record 4 of Set 3 | dabakala
# Processing Record 5 of Set 3 | arraial do cabo
# Processing Record 6 of Set 3 | nazret
# Processing Record 7 of Set 3 | vestmannaeyjar
# Processing Record 8 of Set 3 | olecko
# Processing Record 9 of Set 3 | merauke
# Processing Record 10 of Set 3 | hithadhoo
# Processing Record 11 of Set 3 | sibu
# Processing Record 12 of Set 3 | severo-yeniseyskiy
# Processing Record 13 of Set 3 | labuhan
# Processing Record 14 of Set 3 | bredasdorp
# Processing Record 15 of Set 3 | ternate
# Processing Record 16 of Set 3 | santa marta de tormes
# Processing Record 17 of Set 3 | nhulunbuy
# Processing Record 18 of Set 3 | moron
# Processing Record 19 of Set 3 | gawler
# Processing Record 20 of Set 3 | sao felix do xingu
# Processing Record 21 of Set 3 | buzmeyin
# Processing Record 22 of Set 3 | chuy
# Processing Record 23 of Set 3 | roebourne
# Processing Record 24 of Set 3 | hobart
# Processing Record 25 of Set 3 | grand gaube
# Processing Record 26 of Set 3 | wukari
# Processing Record 27 of Set 3 | lebu
# Processing Record 28 of Set 3 | champaign
# Processing Record 29 of Set 3 | castro
# Processing Record 30 of Set 3 | almaznyy
# Processing Record 31 of Set 3 | hambantota
# Processing Record 32 of Set 3 | kidal
# Processing Record 33 of Set 3 | nanortalik
# Processing Record 34 of Set 3 | aksarka
# Processing Record 35 of Set 3 | nikolskoye
# Processing Record 36 of Set 3 | salalah
# Processing Record 37 of Set 3 | yanam
# Processing Record 38 of Set 3 | ust-tsilma
# Processing Record 39 of Set 3 | sioux lookout
# Processing Record 40 of Set 3 | sheboygan
# Processing Record 41 of Set 3 | beringovskiy
# Processing Record 42 of Set 3 | sola
# Processing Record 43 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 3 | iskateley
# Processing Record 45 of Set 3 | vallenar
# Processing Record 46 of Set 3 | nizhniy odes
# Processing Record 47 of Set 3 | nieuw amsterdam
# Processing Record 48 of Set 3 | kudahuvadhoo
# Processing Record 49 of Set 3 | tomatlan
# Processing Record 50 of Set 3 | chama
# Processing Record 1 of Set 4 | saint-philippe
# Processing Record 2 of Set 4 | nouadhibou
# Processing Record 3 of Set 4 | luganville
# Processing Record 4 of Set 4 | kavieng
# Processing Record 5 of Set 4 | bilma
# Processing Record 6 of Set 4 | victor harbor
# Processing Record 7 of Set 4 | pisco
# Processing Record 8 of Set 4 | basco
# Processing Record 9 of Set 4 | kilindoni
# Processing Record 10 of Set 4 | codrington
# Processing Record 11 of Set 4 | kropotkin
# Processing Record 12 of Set 4 | noumea
# Processing Record 13 of Set 4 | bluff
# Processing Record 14 of Set 4 | gaozhou
# Processing Record 15 of Set 4 | mar del plata
# Processing Record 16 of Set 4 | namibe
# Processing Record 17 of Set 4 | port elizabeth
# Processing Record 18 of Set 4 | zabaykalsk
# Processing Record 19 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 4 | isangel
# Processing Record 22 of Set 4 | bridlington
# Processing Record 23 of Set 4 | komsomolskiy
# Processing Record 24 of Set 4 | sinnamary
# Processing Record 25 of Set 4 | iqaluit
# Processing Record 26 of Set 4 | kincardine
# Processing Record 27 of Set 4 | mount pleasant
# Processing Record 28 of Set 4 | esperance
# Processing Record 29 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 4 | najran
# Processing Record 31 of Set 4 | longyearbyen
# Processing Record 32 of Set 4 | bulgan
# Processing Record 33 of Set 4 | sibolga
# Processing Record 34 of Set 4 | kyra
# Processing Record 35 of Set 4 | royan
# Processing Record 36 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 38 of Set 4 | nishihara
# Processing Record 39 of Set 4 | alexandria
# Processing Record 40 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 4 | tonstad
# Processing Record 42 of Set 4 | mandalgovi
# Processing Record 43 of Set 4 | chany
# Processing Record 44 of Set 4 | tuktoyaktuk
# Processing Record 45 of Set 4 | severo-kurilsk
# Processing Record 46 of Set 4 | avarua
# Processing Record 47 of Set 4 | lagoa
# Processing Record 48 of Set 4 | kimparana
# Processing Record 49 of Set 4 | vung tau
# Processing Record 50 of Set 4 | manokwari
# Processing Record 1 of Set 5 | caravelas
# Processing Record 2 of Set 5 | ratnagiri
# Processing Record 3 of Set 5 | san francisco
# Processing Record 4 of Set 5 | tachikawa
# Processing Record 5 of Set 5 | mount isa
# Processing Record 6 of Set 5 | tucurui
# Processing Record 7 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 8 of Set 5 | kimberley
# Processing Record 9 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 10 of Set 5 | rincon
# Processing Record 11 of Set 5 | ahipara
# Processing Record 12 of Set 5 | puerto baquerizo moreno
# Processing Record 13 of Set 5 | mayo
# Processing Record 14 of Set 5 | atasu
# Processing Record 15 of Set 5 | la rochelle
# Processing Record 16 of Set 5 | marshall
# Processing Record 17 of Set 5 | ixtapa
# Processing Record 18 of Set 5 | burica
# City not found. Skipping...
# Processing Record 19 of Set 5 | labuan
# Processing Record 20 of Set 5 | aswan
# Processing Record 21 of Set 5 | cidreira
# Processing Record 22 of Set 5 | mehamn
# Processing Record 23 of Set 5 | polovinnoye
# Processing Record 24 of Set 5 | comodoro rivadavia
# Processing Record 25 of Set 5 | olafsvik
# Processing Record 26 of Set 5 | upernavik
# Processing Record 27 of Set 5 | werda
# Processing Record 28 of Set 5 | zhangjiakou
# Processing Record 29 of Set 5 | carnarvon
# Processing Record 30 of Set 5 | tsienyane
# City not found. Skipping...
# Processing Record 31 of Set 5 | saskylakh
# Processing Record 32 of Set 5 | kununurra
# Processing Record 33 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 5 | notre-dame-du-lac
# Processing Record 35 of Set 5 | sao filipe
# Processing Record 36 of Set 5 | khandyga
# Processing Record 37 of Set 5 | horni benesov
# Processing Record 38 of Set 5 | skibbereen
# Processing Record 39 of Set 5 | amuntai
# Processing Record 40 of Set 5 | santa marta
# Processing Record 41 of Set 5 | kruisfontein
# Processing Record 42 of Set 5 | erenhot
# Processing Record 43 of Set 5 | flinders
# Processing Record 44 of Set 5 | nova olinda do norte
# Processing Record 45 of Set 5 | eirunepe
# Processing Record 46 of Set 5 | namatanai
# Processing Record 47 of Set 5 | kutum
# Processing Record 48 of Set 5 | camopi
# Processing Record 49 of Set 5 | nawalgarh
# Processing Record 50 of Set 5 | baruun-urt
# Processing Record 1 of Set 6 | antalaha
# Processing Record 2 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 6 | wells
# Processing Record 5 of Set 6 | taoudenni
# Processing Record 6 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 7 of Set 6 | buin
# Processing Record 8 of Set 6 | purgstall
# Processing Record 9 of Set 6 | ambilobe
# Processing Record 10 of Set 6 | cherskiy
# Processing Record 11 of Set 6 | tashtyp
# Processing Record 12 of Set 6 | hasaki
# Processing Record 13 of Set 6 | ahuimanu
# Processing Record 14 of Set 6 | roald
# Processing Record 15 of Set 6 | geraldton
# Processing Record 16 of Set 6 | hue
# Processing Record 17 of Set 6 | coihaique
# Processing Record 18 of Set 6 | campoverde
# Processing Record 19 of Set 6 | dhidhdhoo
# Processing Record 20 of Set 6 | kharan
# Processing Record 21 of Set 6 | san juan
# Processing Record 22 of Set 6 | tilichiki
# Processing Record 23 of Set 6 | kitami
# Processing Record 24 of Set 6 | marrakesh
# Processing Record 25 of Set 6 | barranca
# Processing Record 26 of Set 6 | moree
# Processing Record 27 of Set 6 | timra
# Processing Record 28 of Set 6 | gouyave
# Processing Record 29 of Set 6 | aksu
# Processing Record 30 of Set 6 | punta cardon
# Processing Record 31 of Set 6 | maraba
# Processing Record 32 of Set 6 | de aar
# Processing Record 33 of Set 6 | dingle
# Processing Record 34 of Set 6 | mahebourg
# Processing Record 35 of Set 6 | margate
# Processing Record 36 of Set 6 | vao
# Processing Record 37 of Set 6 | alta floresta
# Processing Record 38 of Set 6 | cabo san lucas
# Processing Record 39 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 6 | telford
# Processing Record 41 of Set 6 | kavaratti
# Processing Record 42 of Set 6 | mercedes
# Processing Record 43 of Set 6 | college
# Processing Record 44 of Set 6 | socorro
# Processing Record 45 of Set 6 | egvekinot
# Processing Record 46 of Set 6 | mezen
# Processing Record 47 of Set 6 | miram shah
# Processing Record 48 of Set 6 | antofagasta
# Processing Record 49 of Set 6 | kuching
# Processing Record 50 of Set 6 | yelnya
# Processing Record 1 of Set 7 | camacha
# Processing Record 2 of Set 7 | le passage
# Processing Record 3 of Set 7 | dudinka
# Processing Record 4 of Set 7 | brae
# Processing Record 5 of Set 7 | nizwa
# Processing Record 6 of Set 7 | tutoia
# Processing Record 7 of Set 7 | cap malheureux
# Processing Record 8 of Set 7 | pangai
# Processing Record 9 of Set 7 | san cristobal
# Processing Record 10 of Set 7 | asau
# Processing Record 11 of Set 7 | fez
# Processing Record 12 of Set 7 | shelburne
# Processing Record 13 of Set 7 | loa janan
# Processing Record 14 of Set 7 | kemin
# Processing Record 15 of Set 7 | airai
# Processing Record 16 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 17 of Set 7 | fairbanks
# Processing Record 18 of Set 7 | westport
# Processing Record 19 of Set 7 | klaksvik
# Processing Record 20 of Set 7 | galle
# Processing Record 21 of Set 7 | muravlenko
# Processing Record 22 of Set 7 | sivaki
# Processing Record 23 of Set 7 | faanui
# Processing Record 24 of Set 7 | vaini
# Processing Record 25 of Set 7 | port hardy
# Processing Record 26 of Set 7 | holme
# Processing Record 27 of Set 7 | iquitos
# Processing Record 28 of Set 7 | khandbari
# Processing Record 29 of Set 7 | chifeng
# Processing Record 30 of Set 7 | vila velha
# Processing Record 31 of Set 7 | lompoc
# Processing Record 32 of Set 7 | townsville
# Processing Record 33 of Set 7 | alofi
# Processing Record 34 of Set 7 | pho chai
# Processing Record 35 of Set 7 | yatou
# Processing Record 36 of Set 7 | japura
# Processing Record 37 of Set 7 | kupang
# Processing Record 38 of Set 7 | guerrero negro
# Processing Record 39 of Set 7 | mabaruma
# Processing Record 40 of Set 7 | cariamanga
# Processing Record 41 of Set 7 | obregon
# Processing Record 42 of Set 7 | dabat
# Processing Record 43 of Set 7 | ligayan
# Processing Record 44 of Set 7 | mirpur sakro
# Processing Record 45 of Set 7 | hamilton
# Processing Record 46 of Set 7 | sangin
# Processing Record 47 of Set 7 | hammerfest
# Processing Record 48 of Set 7 | bethel
# Processing Record 49 of Set 7 | dawlatabad
# Processing Record 50 of Set 7 | bako
# Processing Record 1 of Set 8 | touros
# Processing Record 2 of Set 8 | kisangani
# Processing Record 3 of Set 8 | suhbaatar
# Processing Record 4 of Set 8 | acapulco
# Processing Record 5 of Set 8 | chake chake
# Processing Record 6 of Set 8 | swan hill
# Processing Record 7 of Set 8 | seymchan
# Processing Record 8 of Set 8 | bud
# Processing Record 9 of Set 8 | ergani
# Processing Record 10 of Set 8 | mumford
# Processing Record 11 of Set 8 | bull savanna
# Processing Record 12 of Set 8 | sao joao da barra
# Processing Record 13 of Set 8 | ancud
# Processing Record 14 of Set 8 | qesarya
# Processing Record 15 of Set 8 | taltal
# Processing Record 16 of Set 8 | russell
# Processing Record 17 of Set 8 | kovylkino
# Processing Record 18 of Set 8 | tornio
# Processing Record 19 of Set 8 | sechura
# Processing Record 20 of Set 8 | mushie
# Processing Record 21 of Set 8 | shenkursk
# Processing Record 22 of Set 8 | santa fe do sul
# Processing Record 23 of Set 8 | poum
# Processing Record 24 of Set 8 | businga
# Processing Record 25 of Set 8 | macau
# Processing Record 26 of Set 8 | putyatino
# Processing Record 27 of Set 8 | tynda
# Processing Record 28 of Set 8 | matara
# Processing Record 29 of Set 8 | ekhabi
# Processing Record 30 of Set 8 | alzamay
# Processing Record 31 of Set 8 | zgierz
# Processing Record 32 of Set 8 | kenora
# Processing Record 33 of Set 8 | talnakh
# Processing Record 34 of Set 8 | gujar khan
# Processing Record 35 of Set 8 | pangnirtung
# Processing Record 36 of Set 8 | ilulissat
# Processing Record 37 of Set 8 | gavle
# Processing Record 38 of Set 8 | hermosillo
# Processing Record 39 of Set 8 | okahandja
# Processing Record 40 of Set 8 | richards bay
# Processing Record 41 of Set 8 | barinitas
# Processing Record 42 of Set 8 | victoria
# Processing Record 43 of Set 8 | karratha
# Processing Record 44 of Set 8 | palana
# Processing Record 45 of Set 8 | lavrentiya
# Processing Record 46 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 47 of Set 8 | constitucion
# Processing Record 48 of Set 8 | kibre mengist
# Processing Record 49 of Set 8 | acuna
# City not found. Skipping...
# Processing Record 50 of Set 8 | leningradskiy
# Processing Record 1 of Set 9 | palmer
# Processing Record 2 of Set 9 | kurchum
# Processing Record 3 of Set 9 | baykit
# Processing Record 4 of Set 9 | fukue
# Processing Record 5 of Set 9 | hikari
# Processing Record 6 of Set 9 | rabo de peixe
# Processing Record 7 of Set 9 | smirnykh
# Processing Record 8 of Set 9 | aksha
# Processing Record 9 of Set 9 | padang
# Processing Record 10 of Set 9 | saint george
# Processing Record 11 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 9 | makakilo city
# Processing Record 13 of Set 9 | aklavik
# Processing Record 14 of Set 9 | ucluelet
# Processing Record 15 of Set 9 | baoma
# Processing Record 16 of Set 9 | dakoro
# Processing Record 17 of Set 9 | vila praia de ancora
# Processing Record 18 of Set 9 | muyezerskiy
# Processing Record 19 of Set 9 | muros
# Processing Record 20 of Set 9 | marawi
# Processing Record 21 of Set 9 | ouadda
# Processing Record 22 of Set 9 | sydney
# Processing Record 23 of Set 9 | beloha
# Processing Record 24 of Set 9 | puri
# Processing Record 25 of Set 9 | san patricio
# Processing Record 26 of Set 9 | mount gambier
# Processing Record 27 of Set 9 | laguna
# Processing Record 28 of Set 9 | mayor pablo lagerenza
# Processing Record 29 of Set 9 | saskatoon
# Processing Record 30 of Set 9 | port augusta
# Processing Record 31 of Set 9 | portland
# Processing Record 32 of Set 9 | tvoroyri
# Processing Record 33 of Set 9 | altamira
# Processing Record 34 of Set 9 | severnyy
# Processing Record 35 of Set 9 | zacualpan
# Processing Record 36 of Set 9 | sabha
# Processing Record 37 of Set 9 | pingyin
# Processing Record 38 of Set 9 | belen
# Processing Record 39 of Set 9 | hualmay
# Processing Record 40 of Set 9 | yuncheng
# Processing Record 41 of Set 9 | ciudad arce
# Processing Record 42 of Set 9 | conde
# Processing Record 43 of Set 9 | morant bay
# Processing Record 44 of Set 9 | hov
# Processing Record 45 of Set 9 | araouane
# Processing Record 46 of Set 9 | itupiranga
# Processing Record 47 of Set 9 | mantua
# Processing Record 48 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 49 of Set 9 | porto belo
# Processing Record 50 of Set 9 | donetsk
# Processing Record 1 of Set 10 | dolores
# Processing Record 2 of Set 10 | moose factory
# Processing Record 3 of Set 10 | coquimbo
# Processing Record 4 of Set 10 | bukama
# Processing Record 5 of Set 10 | suntar
# Processing Record 6 of Set 10 | clarence town
# Processing Record 7 of Set 10 | chapais
# Processing Record 8 of Set 10 | lucea
# Processing Record 9 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 10 | bom jesus
# Processing Record 11 of Set 10 | lalmohan
# Processing Record 12 of Set 10 | kijang
# Processing Record 13 of Set 10 | poya
# Processing Record 14 of Set 10 | teahupoo
# Processing Record 15 of Set 10 | yulara
# Processing Record 16 of Set 10 | gravelbourg
# Processing Record 17 of Set 10 | sitka
# Processing Record 18 of Set 10 | hofn
# Processing Record 19 of Set 10 | arrecife
# Processing Record 20 of Set 10 | benghazi
# Processing Record 21 of Set 10 | zhuhai
# Processing Record 22 of Set 10 | yeppoon
# Processing Record 23 of Set 10 | vrangel
# Processing Record 24 of Set 10 | batsfjord
# Processing Record 25 of Set 10 | ayan
# Processing Record 26 of Set 10 | moen
# Processing Record 27 of Set 10 | prieska
# Processing Record 28 of Set 10 | fort nelson
# Processing Record 29 of Set 10 | bayangol
# Processing Record 30 of Set 10 | bayevo
# Processing Record 31 of Set 10 | bolshiye uki
# City not found. Skipping...
# Processing Record 32 of Set 10 | cabedelo
# Processing Record 33 of Set 10 | bandarbeyla
# Processing Record 34 of Set 10 | kirkuk
# Processing Record 35 of Set 10 | skibotn
# Processing Record 36 of Set 10 | barsovo
# Processing Record 37 of Set 10 | husavik
# Processing Record 38 of Set 10 | moissala
# Processing Record 39 of Set 10 | abha
# Processing Record 40 of Set 10 | sur
# Processing Record 41 of Set 10 | daxian
# City not found. Skipping...
# Processing Record 42 of Set 10 | shu
# Processing Record 43 of Set 10 | baoqing
# Processing Record 44 of Set 10 | tiarei
# Processing Record 45 of Set 10 | demyanovo
# Processing Record 46 of Set 10 | goderich
# Processing Record 47 of Set 10 | mtwango
# Processing Record 48 of Set 10 | lephepe
# City not found. Skipping...
# Processing Record 49 of Set 10 | kenai
# Processing Record 50 of Set 10 | paros
# Processing Record 1 of Set 11 | port hedland
# Processing Record 2 of Set 11 | komatipoort
# Processing Record 3 of Set 11 | jaguaquara
# Processing Record 4 of Set 11 | kajaani
# Processing Record 5 of Set 11 | barkhan
# Processing Record 6 of Set 11 | san quintin
# Processing Record 7 of Set 11 | salinas
# Processing Record 8 of Set 11 | massaguet
# Processing Record 9 of Set 11 | syracuse
# Processing Record 10 of Set 11 | kloulklubed
# Processing Record 11 of Set 11 | havre-saint-pierre
# Processing Record 12 of Set 11 | itarema
# Processing Record 13 of Set 11 | teguldet
# Processing Record 14 of Set 11 | alice springs
# Processing Record 15 of Set 11 | agva
# City not found. Skipping...
# Processing Record 16 of Set 11 | paamiut
# Processing Record 17 of Set 11 | chipinge
# Processing Record 18 of Set 11 | tual
# Processing Record 19 of Set 11 | ulladulla
# Processing Record 20 of Set 11 | saint-leu
# Processing Record 21 of Set 11 | clonakilty
# Processing Record 22 of Set 11 | qarchak
# Processing Record 23 of Set 11 | hami
# Processing Record 24 of Set 11 | morondava
# Processing Record 25 of Set 11 | yar-sale
# Processing Record 26 of Set 11 | tuatapere
# Processing Record 27 of Set 11 | corumba
# Processing Record 28 of Set 11 | tshikapa
# Processing Record 29 of Set 11 | gracac
# Processing Record 30 of Set 11 | zalantun
# Processing Record 31 of Set 11 | huilong
# Processing Record 32 of Set 11 | opobo
# City not found. Skipping...
# Processing Record 33 of Set 11 | krasnoselkup
# Processing Record 34 of Set 11 | yangambi
# Processing Record 35 of Set 11 | phalodi
# Processing Record 36 of Set 11 | calvinia
# Processing Record 37 of Set 11 | port macquarie
# Processing Record 38 of Set 11 | namtsy
# Processing Record 39 of Set 11 | zboriv
# Processing Record 40 of Set 11 | winnemucca
# Processing Record 41 of Set 11 | fiumicino
# Processing Record 42 of Set 11 | kahului
# Processing Record 43 of Set 11 | surt
# Processing Record 44 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 45 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 46 of Set 11 | saint-georges
# Processing Record 47 of Set 11 | atambua
# Processing Record 48 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 49 of Set 11 | santa cruz
# Processing Record 50 of Set 11 | wangkui
# Processing Record 1 of Set 12 | rocha
# Processing Record 2 of Set 12 | banda aceh
# Processing Record 3 of Set 12 | oak ridge
# Processing Record 4 of Set 12 | lorengau
# Processing Record 5 of Set 12 | ingham
# Processing Record 6 of Set 12 | la ronge
# Processing Record 7 of Set 12 | fort payne
# Processing Record 8 of Set 12 | huarmey
# Processing Record 9 of Set 12 | sisimiut
# Processing Record 10 of Set 12 | takhatgarh
# Processing Record 11 of Set 12 | tigre
# Processing Record 12 of Set 12 | malgrat de mar
# Processing Record 13 of Set 12 | torbay
# Processing Record 14 of Set 12 | asfi
# Processing Record 15 of Set 12 | letogo
# City not found. Skipping...
# Processing Record 16 of Set 12 | talawdi
# City not found. Skipping...
# Processing Record 17 of Set 12 | quatre cocos
# Processing Record 18 of Set 12 | peniche
# Processing Record 19 of Set 12 | changji
# Processing Record 20 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 12 | novikovo
# Processing Record 22 of Set 12 | toora-khem
# Processing Record 23 of Set 12 | meridian
# Processing Record 24 of Set 12 | kundiawa
# Processing Record 25 of Set 12 | dezful
# Processing Record 26 of Set 12 | zeewolde
# Processing Record 27 of Set 12 | lufilufi
# Processing Record 28 of Set 12 | northam
# Processing Record 29 of Set 12 | rawson
# Processing Record 30 of Set 12 | umm bab
# Processing Record 31 of Set 12 | tekirdag
# Processing Record 32 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 33 of Set 12 | oranjemund
# Processing Record 34 of Set 12 | cochrane
# Processing Record 35 of Set 12 | san jose
# Processing Record 36 of Set 12 | fairmont
# Processing Record 37 of Set 12 | jalu
# Processing Record 38 of Set 12 | haines junction
# Processing Record 39 of Set 12 | dapaong
# Processing Record 40 of Set 12 | newton
# Processing Record 41 of Set 12 | verkhoshizhemye
# Processing Record 42 of Set 12 | kemijarvi
# Processing Record 43 of Set 12 | saint-pierre
# Processing Record 44 of Set 12 | hilpoltstein
# Processing Record 45 of Set 12 | chabahar
# Processing Record 46 of Set 12 | aykhal
# Processing Record 47 of Set 12 | bouza
# Processing Record 48 of Set 12 | houston
# Processing Record 49 of Set 12 | sassandra
# Processing Record 50 of Set 12 | ornskoldsvik
# Processing Record 1 of Set 13 | agirish
# Processing Record 2 of Set 13 | ugoofaaru
# Processing Record 3 of Set 13 | pelym
# Processing Record 4 of Set 13 | mareeba
# Processing Record 5 of Set 13 | ballina
# Processing Record 6 of Set 13 | la union
# Processing Record 7 of Set 13 | orsha
# Processing Record 8 of Set 13 | ransang
# Processing Record 9 of Set 13 | yirol
# City not found. Skipping...
# Processing Record 10 of Set 13 | talbahat
# Processing Record 11 of Set 13 | shenjiamen
# Processing Record 12 of Set 13 | tshela
# Processing Record 13 of Set 13 | dunedin
# Processing Record 14 of Set 13 | san carlos de bariloche
# Processing Record 15 of Set 13 | disna
# Processing Record 16 of Set 13 | saint-francois
# Processing Record 17 of Set 13 | blonay
# Processing Record 18 of Set 13 | chitungwiza
# Processing Record 19 of Set 13 | juneau
# Processing Record 20 of Set 13 | nome
# Processing Record 21 of Set 13 | lasa
# Processing Record 22 of Set 13 | astoria
# Processing Record 23 of Set 13 | ambalavao
# Processing Record 24 of Set 13 | chicama
# Processing Record 25 of Set 13 | gorontalo
# Processing Record 26 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 27 of Set 13 | beecher
# Processing Record 28 of Set 13 | asmara
# Processing Record 29 of Set 13 | hirara
# Processing Record 30 of Set 13 | inhambane
# Processing Record 31 of Set 13 | camana
# Processing Record 32 of Set 13 | linkou
# Processing Record 33 of Set 13 | dongsheng
# Processing Record 34 of Set 13 | panorama
# Processing Record 35 of Set 13 | jutai
# Processing Record 36 of Set 13 | opuwo
# Processing Record 37 of Set 13 | alihe
# Processing Record 38 of Set 13 | toamasina
# Processing Record 39 of Set 13 | dickson
# Processing Record 40 of Set 13 | cabra
# Processing Record 41 of Set 13 | camaqua
# Processing Record 42 of Set 13 | erzin
# Processing Record 43 of Set 13 | gogapur
# Processing Record 44 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 45 of Set 13 | stettler
# Processing Record 46 of Set 13 | general nakar
# Processing Record 47 of Set 13 | naftah
# City not found. Skipping...
# Processing Record 48 of Set 13 | dauphin
# Processing Record 49 of Set 13 | patrocinio
# Processing Record 50 of Set 13 | cockburn town
# Processing Record 1 of Set 14 | ketchikan
# Processing Record 2 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 3 of Set 14 | verkhneuralsk
# Processing Record 4 of Set 14 | wagar
# Processing Record 5 of Set 14 | kuandian
# Processing Record 6 of Set 14 | shimoda
# Processing Record 7 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 8 of Set 14 | pampas
# Processing Record 9 of Set 14 | forestville
# Processing Record 10 of Set 14 | ust-omchug
# Processing Record 11 of Set 14 | ponnani
# Processing Record 12 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 13 of Set 14 | manbij
# Processing Record 14 of Set 14 | whitley bay
# Processing Record 15 of Set 14 | katobu
# Processing Record 16 of Set 14 | cuervos
# Processing Record 17 of Set 14 | kiruna
# Processing Record 18 of Set 14 | anadyr
# Processing Record 19 of Set 14 | kamenka
# Processing Record 20 of Set 14 | amambai
# Processing Record 21 of Set 14 | north decatur
# Processing Record 22 of Set 14 | swidwin
# Processing Record 23 of Set 14 | kushima
# Processing Record 24 of Set 14 | birao
# Processing Record 25 of Set 14 | port lincoln
# Processing Record 26 of Set 14 | neustadt
# Processing Record 27 of Set 14 | sebezh
# Processing Record 28 of Set 14 | takoradi
# Processing Record 29 of Set 14 | nemuro
# Processing Record 30 of Set 14 | vanimo
# Processing Record 31 of Set 14 | moscow
# Processing Record 32 of Set 14 | konevo
# Processing Record 33 of Set 14 | saint anthony
# Processing Record 34 of Set 14 | atherton
# Processing Record 35 of Set 14 | durban
# Processing Record 36 of Set 14 | mackay
# Processing Record 37 of Set 14 | ballangen
# Processing Record 38 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 14 | champerico
# Processing Record 40 of Set 14 | lubbock
# Processing Record 41 of Set 14 | nargana
# Processing Record 42 of Set 14 | teguise
# Processing Record 43 of Set 14 | jacqueville
# Processing Record 44 of Set 14 | prado
# Processing Record 45 of Set 14 | monrovia
# Processing Record 46 of Set 14 | los angeles
# Processing Record 47 of Set 14 | riohacha
# Processing Record 48 of Set 14 | encruzilhada do sul
# Processing Record 49 of Set 14 | burnie
# Processing Record 50 of Set 14 | dicabisagan
# Processing Record 1 of Set 15 | gat
# Processing Record 2 of Set 15 | zyryanka
# Processing Record 3 of Set 15 | tingrela
# City not found. Skipping...
# Processing Record 4 of Set 15 | mogadishu
# Processing Record 5 of Set 15 | mwene-ditu
# Processing Record 6 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 15 | lalomanu
# City not found. Skipping...
# Processing Record 8 of Set 15 | oyama
# Processing Record 9 of Set 15 | saquarema
# Processing Record 10 of Set 15 | pirapo
# Processing Record 11 of Set 15 | miandrivazo
# Processing Record 12 of Set 15 | salaya
# Processing Record 13 of Set 15 | sungaipenuh
# Processing Record 14 of Set 15 | bonavista
# Processing Record 15 of Set 15 | itaituba
# Processing Record 16 of Set 15 | tautira
# Processing Record 17 of Set 15 | walvis bay
# Processing Record 18 of Set 15 | kaeo
# Processing Record 19 of Set 15 | leh
# Processing Record 20 of Set 15 | tripoli
# Processing Record 21 of Set 15 | belmonte
# Processing Record 22 of Set 15 | harper
# Processing Record 23 of Set 15 | teya
# Processing Record 24 of Set 15 | srednekolymsk
# Processing Record 25 of Set 15 | umea
# Processing Record 26 of Set 15 | payakumbuh
# Processing Record 27 of Set 15 | sigli
# Processing Record 28 of Set 15 | bhandara
# Processing Record 29 of Set 15 | nata
# Processing Record 30 of Set 15 | asilah
# Processing Record 31 of Set 15 | kinablangan
# Processing Record 32 of Set 15 | dourbali
# Processing Record 33 of Set 15 | sao mateus
# Processing Record 34 of Set 15 | piet retief
# Processing Record 35 of Set 15 | huambo
# Processing Record 36 of Set 15 | mala
# Processing Record 37 of Set 15 | taunggyi
# Processing Record 38 of Set 15 | zaysan
# Processing Record 39 of Set 15 | inta
# Processing Record 40 of Set 15 | santa ana
# Processing Record 41 of Set 15 | smithers
# Processing Record 42 of Set 15 | amahai
# Processing Record 43 of Set 15 | abnub
# Processing Record 44 of Set 15 | tahoua
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#               City  Cloudiness Country Current Description  Humidity      Lat  \
# 0          Angoche          94      MZ     overcast clouds        81 -16.2325
# 1           Broome          90      US          light rain        77  42.2506
# 2  Bambous Virieux          23      MU          few clouds        73 -20.3428
# 3       Chokurdakh         100      RU     overcast clouds        99  70.6333
# 4            Junin         100      AR     overcast clouds        56 -34.5838
#
#         Lng  Max Temp  Wind Speed
# 0   39.9086     78.51        6.20
# 1  -75.8330     35.62        3.00
# 2   57.7575     74.21       10.80
# 3  147.9167    -15.12        6.31
# 4  -60.9433     62.96        8.79

# %%
city_data_df = city_data_df[["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]]
city_data_df.head()
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Angoche      MZ -16.2325   39.9086     78.51        81          94
# 1           Broome      US  42.2506  -75.8330     35.62        77          90
# 2  Bambous Virieux      MU -20.3428   57.7575     74.21        73          23
# 3       Chokurdakh      RU  70.6333  147.9167    -15.12        99         100
# 4            Junin      AR -34.5838  -60.9433     62.96        56         100
#
#    Wind Speed Current Description
# 0        6.20     overcast clouds
# 1        3.00          light rain
# 2       10.80          few clouds
# 3        6.31     overcast clouds
# 4        8.79     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
